# %% [markdown]
# ### PROGRAM 07: KMEANS AND EM ALGORITHM

# %%
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
import sklearn.metrics as sm
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("datasets/kmeans_dataset.csv")
df.head()
# Out:
#           V1         V2
# 0   2.072345  -3.241693
# 1  17.936710  15.784810
# 2   1.083576   7.319176
# 3  11.120670  14.406780
# 4  23.711550   2.557729

# %%
df.shape
# Out:
# (3000, 2)

# %%
v1 = df['V1'].values
v2 = df['V2'].values

# %%
v1
# Out:
# array([ 2.072345, 17.93671 ,  1.083576, ..., 64.46532 , 90.72282 ,
#        64.87976 ])

# %%
v2
# Out:
# array([ -3.241693,  15.78481 ,   7.319176, ..., -10.50136 , -12.25584 ,
#        -24.87731 ])

# %%
plt.scatter(v1, v2, c='black', s=7)
plt.title('Dataset')
# Out:
# Text(0.5, 1.0, 'Dataset')

# %%
X = np.array(list(zip(v1, v2)))
X
# Out:
# array([[  2.072345,  -3.241693],
#        [ 17.93671 ,  15.78481 ],
#        [  1.083576,   7.319176],
#        ...,
#        [ 64.46532 , -10.50136 ],
#        [ 90.72282 , -12.25584 ],
#        [ 64.87976 , -24.87731 ]])

# %%
# number of clusters
k = 3
kmeans = KMeans(n_clusters=k)
kmeans = kmeans.fit(X)
labels = kmeans.predict(X)
centroids = kmeans.cluster_centers_
centroids
# Out:
# array([[  9.4780459 ,  10.686052  ],
#        [ 40.68362784,  59.71589274],
#        [ 69.92418447, -10.11964119]])

# %%
plt.title('KMeans')
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='rainbow')
plt.scatter(centroids[:, 0], centroids[:, 1], marker='*', color='black')

# %%
# number of clusters
k = 4
kmeans = KMeans(n_clusters=k)
kmeans = kmeans.fit(X)
labels = kmeans.predict(X)
centroids = kmeans.cluster_centers_
centroids
# Out:
# array([[  9.43391214,  10.63898036],
#        [ 69.92418447, -10.11964119],
#        [ 32.19365116,  59.3639177 ],
#        [ 48.46934394,  59.94703432]])

# %%
plt.title('KMeans')
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='rainbow')
plt.scatter(centroids[:, 0], centroids[:, 1], marker='*', color='black')

# %%
gm = GaussianMixture(n_components=4).fit(X)
labels = gm.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis')
plt.show()

# %%
print("EM predictions")
probs = gm.predict_proba(X)
print(probs)
print("MEAN:\n", gm.means_)
print("COVARIANCES\n", gm.covariances_)
# Out:
# EM predictions
# [[2.31489325e-14 9.99999998e-01 2.47965279e-09 5.09455879e-13]
#  [6.98408101e-07 9.99996988e-01 3.50096774e-07 1.96335002e-06]
#  [1.27071384e-12 1.00000000e+00 1.80028184e-10 1.78209540e-10]
#  ...
#  [4.05332672e-13 3.26823856e-08 9.99999967e-01 1.31273888e-19]
#  [7.32444536e-20 3.32765648e-15 1.00000000e+00 1.16785079e-28]
#  [8.78334965e-18 7.66474029e-10 9.99999999e-01 9.43352835e-26]]
# MEAN:
#  [[ 46.39456866  58.12178931]
#  [  9.4703013   10.72229502]
#  [ 69.8943173  -10.11313272]
#  [ 33.81617862  61.63569583]]
# COVARIANCES
#  [[[ 60.05147489   7.27461902]
#   [  7.27461902  97.74398535]]
#
#  [[103.7383208    3.99627624]
#   [  3.99627624  96.97319007]]
#
#  [[110.43616681  -0.58666276]
#   [ -0.58666276 106.45210549]]
#
#  [[ 68.507047    11.0871852 ]
#   [ 11.0871852   83.16435922]]]

# %%
gm = GaussianMixture(n_components=3).fit(X)
labels = gm.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis')
plt.show()

# %%
print("EM predictions")
probs = gm.predict_proba(X)
print(probs)
print("MEAN:\n", gm.means_)
print("COVARIANCES\n", gm.covariances_)
# Out:
# EM predictions
# [[1.51560970e-12 2.47857809e-09 9.99999998e-01]
#  [4.99388810e-06 3.50898583e-07 9.99994655e-01]
#  [3.06364433e-10 1.79826264e-10 1.00000000e+00]
#  ...
#  [5.88532728e-13 9.99999967e-01 3.31608645e-08]
#  [1.18181069e-16 1.00000000e+00 3.40814080e-15]
#  [1.17363874e-17 9.99999999e-01 7.83207859e-10]]
# MEAN:
#  [[ 40.68585643  59.70939105]
#  [ 69.89436808 -10.11243325]
#  [  9.46516999  10.71326558]]
# COVARIANCES
#  [[[103.11540751  -1.82258688]
#   [ -1.82258688  94.29478126]]
#
#  [[110.42521599  -0.60038245]
#   [ -0.60038245 106.47434137]]
#
#  [[103.72485985   3.83148201]
#   [  3.83148201  96.80338694]]]
