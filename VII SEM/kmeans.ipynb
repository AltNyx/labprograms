# %%
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
import sklearn.metrics as sm
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("datasets/kmeans_dataset.csv")
df.head()
# Out:
#           V1         V2
# 0   2.072345  -3.241693
# 1  17.936710  15.784810
# 2   1.083576   7.319176
# 3  11.120670  14.406780
# 4  23.711550   2.557729

# %%
df.shape
# Out:
# (3000, 2)

# %%
v1 = df['V1'].values
v2 = df['V2'].values

# %%
v1
# Out:
# array([ 2.072345, 17.93671 ,  1.083576, ..., 64.46532 , 90.72282 ,
#        64.87976 ])

# %%
v2
# Out:
# array([ -3.241693,  15.78481 ,   7.319176, ..., -10.50136 , -12.25584 ,
#        -24.87731 ])

# %%
plt.scatter(v1, v2, c='black', s=7)
plt.title('Dataset')
# Out:
# Text(0.5, 1.0, 'Dataset')

# %%
X = np.array(list(zip(v1, v2)))
X
# Out:
# array([[  2.072345,  -3.241693],
#        [ 17.93671 ,  15.78481 ],
#        [  1.083576,   7.319176],
#        ...,
#        [ 64.46532 , -10.50136 ],
#        [ 90.72282 , -12.25584 ],
#        [ 64.87976 , -24.87731 ]])

# %%
# number of clusters
k = 3
kmeans = KMeans(n_clusters=k)
kmeans = kmeans.fit(X)
labels = kmeans.predict(X)
centroids = kmeans.cluster_centers_
centroids
# Out:
# array([[  9.4780459 ,  10.686052  ],
#        [ 69.92418447, -10.11964119],
#        [ 40.68362784,  59.71589274]])

# %%
plt.title('KMeans')
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='rainbow')
plt.scatter(centroids[:, 0], centroids[:, 1], marker='*', color='black')

# %%
# number of clusters
k = 4
kmeans = KMeans(n_clusters=k)
kmeans = kmeans.fit(X)
labels = kmeans.predict(X)
centroids = kmeans.cluster_centers_
centroids
# Out:
# array([[  9.43391214,  10.63898036],
#        [ 48.12019572,  59.67243019],
#        [ 69.92418447, -10.11964119],
#        [ 31.77293322,  59.66136158]])

# %%
plt.title('KMeans')
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='rainbow')
plt.scatter(centroids[:, 0], centroids[:, 1], marker='*', color='black')

# %%
gm = GaussianMixture(n_components=4).fit(X)
labels = gm.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis')
plt.show()

# %%
print("EM predictions")
probs = gm.predict_proba(X)
print(probs)
print("MEAN:\n", gm.means_)
print("COVARIANCES\n", gm.covariances_)
# Out:
# EM predictions
# [[1.52027633e-12 2.63169093e-13 1.00000000e+00 1.83027257e-18]
#  [4.99769104e-06 1.58219978e-09 9.99995001e-01 2.28918960e-13]
#  [3.07564870e-10 6.91366133e-15 1.00000000e+00 6.82075995e-20]
#  ...
#  [5.92702663e-13 7.66033763e-01 4.08158534e-08 2.33966196e-01]
#  [1.11795472e-16 1.44874664e-02 4.74579236e-15 9.85512534e-01]
#  [1.25175449e-17 7.13327659e-01 1.07878793e-09 2.86672340e-01]]
# MEAN:
#  [[ 40.68602244  59.70939874]
#  [ 63.64137668  -9.47659325]
#  [  9.49982219  10.69598661]
#  [ 76.72668407 -10.81680202]]
# COVARIANCES
#  [[[103.11537012  -1.82797797]
#   [ -1.82797797  94.29774334]]
#
#  [[ 65.43119532   7.39811326]
#   [  7.39811326 107.27060694]]
#
#  [[104.55609123   3.38446416]
#   [  3.38446416  97.04972035]]
#
#  [[ 67.5227433    0.41805127]
#   [  0.41805127 104.567064  ]]]

# %%
gm = GaussianMixture(n_components=3).fit(X)
labels = gm.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis')
plt.show()

# %%
print("EM predictions")
probs = gm.predict_proba(X)
print(probs)
print("MEAN:\n", gm.means_)
print("COVARIANCES\n", gm.covariances_)
# Out:
# EM predictions
# [[9.99999998e-01 2.47857809e-09 1.51560970e-12]
#  [9.99994655e-01 3.50898583e-07 4.99388810e-06]
#  [1.00000000e+00 1.79826264e-10 3.06364433e-10]
#  ...
#  [3.31608645e-08 9.99999967e-01 5.88532728e-13]
#  [3.40814080e-15 1.00000000e+00 1.18181069e-16]
#  [7.83207859e-10 9.99999999e-01 1.17363874e-17]]
# MEAN:
#  [[  9.46516999  10.71326558]
#  [ 69.89436808 -10.11243325]
#  [ 40.68585643  59.70939105]]
# COVARIANCES
#  [[[103.72485985   3.83148201]
#   [  3.83148201  96.80338694]]
#
#  [[110.42521599  -0.60038245]
#   [ -0.60038245 106.47434137]]
#
#  [[103.11540751  -1.82258688]
#   [ -1.82258688  94.29478126]]]
